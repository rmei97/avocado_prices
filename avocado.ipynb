# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
#time series
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA

# %%
load = pd.read_csv('avocado.csv',index_col = 0)
load.rename(columns = {'4046': 'Small','4225': 'Medium','4770': 'Large'}, inplace = True)

# %%
load.shape
# Out:
# (18249, 12)

# %%
load.head()
# Out:
#          Date  AveragePrice  Total Volume    Small     Medium   Large  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
load.tail()
# Out:
#           Date  AveragePrice  Total Volume    Small   Medium   Large  \
# 7   2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 8   2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 9   2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 10  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 11  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 7     13498.67    13066.82      431.85          0.0  organic  2018
# 8      9264.84     8940.04      324.80          0.0  organic  2018
# 9      9394.11     9351.80       42.31          0.0  organic  2018
# 10    10969.54    10919.54       50.00          0.0  organic  2018
# 11    12014.15    11988.14       26.01          0.0  organic  2018
#
#               region
# 7   WestTexNewMexico
# 8   WestTexNewMexico
# 9   WestTexNewMexico
# 10  WestTexNewMexico
# 11  WestTexNewMexico

# %%
load.describe()
# Out:
#        AveragePrice  Total Volume         Small        Medium         Large  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
load.groupby('type')['AveragePrice'].mean() #organic sells for more, possible angle
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %%
load.groupby('type')['Total Volume'].mean() #a lot more conventional avocados are sold
# Out:
# type
# conventional    1.653213e+06
# organic         4.781121e+04
# Name: Total Volume, dtype: float64

# %%
load.groupby(['year','type'])['AveragePrice'].mean()
# Out:
# year  type
# 2015  conventional    1.077963
#       organic         1.673324
# 2016  conventional    1.105595
#       organic         1.571684
# 2017  conventional    1.294888
#       organic         1.735521
# 2018  conventional    1.127886
#       organic         1.567176
# Name: AveragePrice, dtype: float64

# %%
load.groupby(['year','type'])['Total Volume'].mean()
# Out:
# year  type
# 2015  conventional    1.530128e+06
#       organic         3.165993e+04
# 2016  conventional    1.670317e+06
#       organic         4.652424e+04
# 2017  conventional    1.665327e+06
#       organic         5.879018e+04
# 2018  conventional    2.058960e+06
#       organic         7.489548e+04
# Name: Total Volume, dtype: float64

# %%
load.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'Small', 'Medium', 'Large',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
load['Date'] = pd.to_datetime(load['Date'])

# %%
load.set_index('Date',inplace = True)

# %%
load[load['region'] == 'Albany']
# Out:
#             AveragePrice  Total Volume    Small     Medium   Large  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...                  ...           ...      ...        ...     ...
# 2018-02-04          1.52       4124.96   118.38     420.36    0.00
# 2018-01-28          1.32       6987.56   433.66     374.96    0.00
# 2018-01-21          1.54       3346.54    14.67     253.01    0.00
# 2018-01-14          1.47       4140.95     7.30     301.87    0.00
# 2018-01-07          1.54       4816.90    43.51     412.17    0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
conventional_df = load[load['type'] == 'conventional']

# %%
conventional_df[conventional_df['region']== 'Albany'] #169 rows * 2 = 338, therefore we have 169 for each type
# Out:
#             AveragePrice  Total Volume    Small     Medium   Large  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...                  ...           ...      ...        ...     ...
# 2018-02-04          1.03     216738.47  7625.65  195725.06  143.53
# 2018-01-28          1.57      93625.03  3101.17   74627.23   55.59
# 2018-01-21          1.69     135196.35  3133.37  116520.88   88.78
# 2018-01-14          1.42      95246.38  2897.41   76570.67   44.00
# 2018-01-07          1.13      98540.22  2940.63   76192.61   42.63
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
organic_df = load[load['type'] == 'organic']
organic_df[organic_df['region'] == 'Albany'].index == conventional_df[conventional_df['region']== 'Albany'].index
#the dates are all the same and are weekly statistics
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %% [markdown]
# # MAP:
# by Date: type -> region -> AvgPrice / Total Volumn

# %%
# def grouper(df,column1,column2 = None,by):
#     '''
#     df = starting dataframe
#     column1 = sort by first column (type)
#     column2 = sort by second column (region)
#     by = returns df with Avgprice/Total Volume
#     '''
#     df[column1][by]

# %%
#type -> Avg Price
conventional_price_df = load[load['type'] == 'conventional']['AveragePrice']
organic_price_df = load[load['type'] == 'organic']['AveragePrice']
conventional_price_df = load[load['type'] == 'conventional']['AveragePrice']
organic_price_df = load[load['type'] == 'organic']['AveragePrice']
